# %%
# %cd ../
# %cd ../
# Out:
# /home/jcx/cloudz/projects/qastats-git/src/qastats
# /home/jcx/cloudz/projects/qastats-git/src

# %%
import qastats
import pandas as pd
import numpy as np
warnings.filterwarnings('ignore')
# Out:
# /home/jcx/miniconda3/envs/qa/lib/python3.10/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
data = pd.read_pickle('qastats/examples/diario_normal.pickle')
data['bench'] = np.random.choice(data['Close'],len(data))

# %%
data.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
stats = qastats.stats.get_daily_stats(data)
stats
# Out:
# /home/jcx/cloudz/projects/qastats-git/src/qastats/stats.py:65: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Calmar Ratio': data.calmar()[0],
# /home/jcx/cloudz/projects/qastats-git/src/qastats/stats.py:93: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Beta Fragility':qa.batting_average(data['Close'], data['bench'])[0],
#                                 Close
# AuM                      000.000.000$
# Start                      2002-07-30
# End                        2023-01-27
# Period                           5161
# Total Return                   361.68
# Factor Return                  288.81
# Ret Corr with Factor            -0.01
# Ret Corr with Factor +          -0.01
# Ret Corr with Factor -          -0.01
# CAGR                             4.42
# Annualized Vol                   9.94
# Max DD                         -21.58
# Calmar Ratio                      0.2
# Sortino Ratio                     1.0
# Omega Ratio                      1.18
# Skew                             0.03
# Kurt                             6.73
# VaR                              -1.0
# CVaR                            -1.58
# Stability                        0.97
# Riesgo Cola                      1.03
# WinRate                          0.54
# Avg ret                          0.05
# Best Day                         5.17
# Worst Day                       -5.05
# Avg Good Day                     0.67
# Avg Bad Day                     -0.67
# Max consecutive wins               11
# Max consecutive losses              6
# Outlier win ratio                8.23
# Outlier loose ratio              2.82
# Profit Factor                    1.18
# CPC Idx                          0.63
# Expectancy                       0.02
# Alpha                            0.07
# Alpha con Modelo +               0.05
# Alpha con Moldelo -             -0.03
# Beta                             -0.0
# Beta con Modelo +               -0.05
# Beta con Modelo -               -0.04
# Beta Fragility                   0.37
# Capture con Modelo +              0.0
# Capture con Modelo -            -0.04
# QA Alpha Capture                -0.09

# %%
dds = qastats.stats.get_drawdown_stats(data['Close'])

# %%
dds
# Out:
#                                         P         S         M        BT  \
# Lehman                               42.0  0.463817  0.087480 -0.956503
# US downgrade/European Debt Crisis    21.0  2.133897  0.196796 -5.045017
# Fukushima                            23.0  0.000000  0.000000  0.000000
# US Housing                           22.0  0.566476  0.086295 -1.919752
# EZB IR Event                         22.0  0.000000  0.000000  0.000000
# Aug07                                23.0  0.498187  0.078259 -1.215328
# Mar08                                20.0  0.000000  0.000000  0.000000
# Sept08                               21.0  0.203053  0.044310  0.000000
# 2009Q1                               39.0  1.117862 -0.240194 -3.158909
# 2009Q2                               63.0  0.752020 -0.045994 -2.514937
# Flash Crash                           3.0  2.177803  0.809279 -1.250150
# Apr14                                21.0  0.000000  0.000000  0.000000
# Oct14                                23.0  0.000000  0.000000  0.000000
# Fall2015                             31.0  0.587736 -0.041934 -1.930340
# Low Volatility Bull Market          648.0  0.383934  0.021964 -1.791618
# GFC Crash                           420.0  0.693735  0.045719 -3.158909
# Recovery                            945.0  0.791205  0.043888 -5.045017
# New Normal                         1441.0  0.573618  0.008849 -4.243185
# Covid                               747.0  0.730767  0.019203 -3.137906
#
#                                          PK
# Lehman                             1.628206
# US downgrade/European Debt Crisis  3.156773
# Fukushima                          0.000000
# US Housing                         0.745723
# EZB IR Event                       0.000000
# Aug07                              1.031867
# Mar08                              0.000000
# Sept08                             0.930507
# 2009Q1                             2.351296
# 2009Q2                             2.581617
# Flash Crash                        3.088750
# Apr14                              0.000000
# Oct14                              0.000000
# Fall2015                           1.009967
# Low Volatility Bull Market         1.694875
# GFC Crash                          5.166181
# Recovery                           3.558148
# New Normal                         2.684774
# Covid                              3.847379

# %%
qastats.stats.show_worst_drawdown_periods(data['Close'])
# Out:
#   Net drawdown in %  Peak date Valley date Recovery date Duration
# 0         21.584419 2012-11-14  2013-11-20    2015-08-11      714
# 1         17.245491 2009-01-02  2009-06-10    2010-05-21      360
# 2         15.687742 2003-06-13  2003-08-13    2005-06-07      518
# 3          11.93748 2016-07-08  2017-05-10    2019-05-30      755
# 4         11.803891 2022-08-01  2022-11-07    2022-12-01       89

# %%
qastats.stats.var_usd(data['Close'])
# Out:
# 10028.09038253699

# %%
qastats.stats.get_vami_diario(data['Close'])
# Out:
# /home/jcx/cloudz/projects/qastats-git/src/qastats/stats.py:218: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   matrix['VAMI'][0] = 1000
# /home/jcx/cloudz/projects/qastats-git/src/qastats/stats.py:218: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   matrix['VAMI'][0] = 1000
# /home/jcx/cloudz/projects/qastats-git/src/qastats/stats.py:221: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   matrix['VAMI'][i] = matrix['VAMI'][i - 1] + (matrix['VAMI'][i - 1] * pct[i])
# /home/jcx/cloudz/projects/qastats-git/src/qastats/stats.py:221: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   matrix['VAMI'][i] = matrix['VAMI'][i - 1] + (matrix['VAMI'][i - 1] * pct[i])
# OK
#                                   VAMI
# Date
# 2002-07-30 04:00:00+00:00         1000
# 2002-07-31 04:00:00+00:00  1000.123895
# 2002-08-01 04:00:00+00:00  1000.180847
# 2002-08-02 04:00:00+00:00  1000.283278
# 2002-08-05 04:00:00+00:00   1000.32741
# ...                                ...
# 2023-01-23 05:00:00+00:00  1013.857044
# 2023-01-24 05:00:00+00:00   1014.00284
# 2023-01-25 05:00:00+00:00  1014.027429
# 2023-01-26 05:00:00+00:00  1013.980257
# 2023-01-27 05:00:00+00:00  1013.954665
#
# [5161 rows x 1 columns]

# %%
qastats.reports.create_return_dd(data)
# Out:
# <h4>JCX@QA-2023 - ALL RIGTHS RESERVED</h4>
# /home/jcx/cloudz/projects/qastats-git/src/qastats/stats.py:65: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Calmar Ratio': data.calmar()[0],
# /home/jcx/cloudz/projects/qastats-git/src/qastats/stats.py:93: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Beta Fragility':qa.batting_average(data['Close'], data['bench'])[0],
# /home/jcx/cloudz/projects/qastats-git/src/qastats/plots.py:509: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_rets = returns.resample("M").apply(lambda x: cumulate_returns(x))
# /home/jcx/cloudz/projects/qastats-git/src/qastats/plots.py:504: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return ep.cum_returns(x)[-1]
# /home/jcx/cloudz/projects/qastats-git/src/qastats/plots.py:510: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   monthly_rets = monthly_rets.to_period()
#    index  Performance  Max Drawdown
# 0     1%       -15.01        -21.13
# 1     5%       -11.66        -18.11
# 2    20%        -2.62        -12.59
# 3    30%         1.00        -11.38
# 4    40%         4.56         -9.76
# 5    50%         7.98         -8.90
# 6    60%        10.57         -8.14
# 7    70%        13.49         -7.45
# 8    80%        17.51         -6.61
# 9    90%        24.53         -5.49
# 10   95%        28.56         -4.97
# 11   99%        36.72         -4.23
# /home/jcx/cloudz/projects/qastats-git/src/qastats/reports.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
